# %%
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Listing 2.1 - map1.py

# %%
import sunpy.map
import sunpy
aiamap = sunpy.map.Map(sunpy.AIA_171_IMAGE)
smap = aiamap.submap([-1200, -200], [-1000, -0])
smap.peek(draw_grid=True)

# %% [markdown]
# # Listing 2.2 - map2.py

# %%
import sunpy
import sunpy.map
import matplotlib.pyplot as plt
compmap = sunpy.map.Map(sunpy.AIA_171_IMAGE, sunpy.RHESSI_IMAGE, composite=True)
compmap.set_levels(1, range(0, 50, 5), percent=True)
compmap.set_colors(1, 'Reds_r')
ax = plt.subplot()
compmap.plot()
ax.axis([200, 600, -600, -200])
plt.show()

# %% [markdown]
# # Listing 2.3 - map3.py

# %%
import sunpy.map
cubemap = sunpy.map.Map(files, cube=True)
cubemap.peek()
# Out:
# ERROR: NameError: name 'files' is not defined [IPython.core.interactiveshell]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7b5f9007d2f5> in <module>()
#       1 import sunpy.map
# ----> 2 cubemap = sunpy.map.Map(files, cube=True)
#       3 cubemap.peek()
#
# NameError: name 'files' is not defined

# %% [markdown]
# # Listing 2.4 - lightcurve.py

# %%
from sunpy import lightcurve
from sunpy.time import TimeRange
tr = TimeRange('2011-06-07 06:00','2011-06-07 08:00')
goes = lightcurve.GOESLightCurve.create(tr)
goes.peek()
print('The max flux is ' + str(goes.data['xrsb'].max()) + ' at ' + str(goes.data['xrsb'].idxmax()))
# Out:
# The max flux is 2.5554e-05 at 2011-06-07 06:41:24.118999

# %% [markdown]
# # Listing 2.5 - spectra.py

# %%
from sunpy.spectra.sources.callisto import CallistoSpectrogram
tstart, tend = "2011-06-07T06:00:00", "2011-06-07T07:45:00"
callisto = CallistoSpectrogram.from_range("BIR", tstart, tend)
callisto_nobg = callisto.subtract_bg()
callisto_nobg.peek(vmin=0)

# %% [markdown]
# # Listing 3.1 - vso1.py

# %%
from sunpy.net import vso
client = vso.VSOClient()
tstart, tend = '2011/6/7 05:30', '2011/6/7 10:30'
lasco_query = client.query(vso.attrs.Time(tstart, tend), vso.attrs.Instrument('lasco'))
lasco_query.num_records()
# Out:
# 40

# %%
lasco_query.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-59a38a789d18> in <module>()
# ----> 1 lasco_query.show()
#
# /Users/schriste/Dropbox/Developer/python/sunpy/sunpy/net/vso/vso.pyc in show(self)
#     220             record.extent.type
#     221               if record.extent.type is not None else 'N/A'
# --> 222           ] for record in self]
#     223         table.insert(0, ['----------','--------','------','----------','----'])
#     224         table.insert(0, ['Start time','End time','Source','Instrument','Type'])
#
# /Users/schriste/anaconda/python.app/Contents/lib/python2.7/_strptime.pyc in _strptime(data_string, format)
#     323     if not found:
#     324         raise ValueError("time data %r does not match format %r" %
# --> 325                          (data_string, format))
#     326     if len(data_string) != found.end():
#     327         raise ValueError("unconverted data remains: %s" %
#
# ValueError: time data '20110607053523' does not match format '%Y-%m-%d %H:%M:%S'

# %%
pathformat = '/data/{instrument}/{detector}/{file}.fits'
results = client.get(coronagraphs, path = pathformat)

# %% [markdown]
# # Listing 3.2 - vso2.py

# %%
condition = (vso.attrs.Detector('cor1') | vso.attrs.Wave(125, 135) | vso.attrs.Wave(165, 175) )
advanced = client.query(vso.attrs.Time(tstart, tend), condition)
advanced.num_records()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-cb4749bbf65b> in <module>()
# ----> 1 condition = (vso.attrs.Detector('cor1') | vso.attrs.Wave(125, 135) | vso.attrs.Wave(165, 175) )
#       2 advanced = client.query(vso.attrs.Time(tstart, tend), condition)
#       3 advanced.num_records()
#
# /Users/schriste/Dropbox/Developer/python/sunpy/sunpy/net/vso/attrs.pyc in __init__(self, wavemin, wavemax)
#      59     def __init__(self, wavemin, wavemax):
#      60         if not all(isinstance(var, u.Quantity) for var in [wavemin, wavemax]):
# ---> 61             raise TypeError("Wave inputs must be astropy Quantities")
#      62
#      63         # VSO just accept inputs as Angstroms, kHz or keV, the following
#
# TypeError: Wave inputs must be astropy Quantities

# %%
advanced.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3db163d20b34> in <module>()
# ----> 1 advanced.show()
#
# NameError: name 'advanced' is not defined

# %% [markdown]
# # Listing 3.3 - hek.py

# %%
from sunpy.net import hek
client = hek.HEKClient()
tstart, tend = '2011/08/09 00:00:00', '2011/08/10 00:00:00'
result = client.query(hek.attrs.Time(tstart, tend), hek.attrs.EventType('FL'))
len(result)
# Out:
# 52

# %% [markdown]
# # Listing 3.4 - hek2.py

# %%
result = client.query(hek.attrs.Time(tstart, tend), hek.attrs.EventType('FL'), hek.attrs.FRM.Name=='SSW Latest Events')
len(result)
# Out:
# 9

# %% [markdown]
# # Listing 3.5 - hek3.py

# %%
result = client.query(hek.attrs.Time(tstart, tend), 
                      hek.attrs.EventType('FL'), 
                      (hek.attrs.Event.Coord1>50) or
                      (hek.attrs.FL.PeakFlux>1000.0))
len(result)
# Out:
# 48

# %% [markdown]
# # Listing 3.6 - hek4.py

# %%
from sunpy.net import hek2vso
h2v = hek2vso.H2VClient()
vso_results = h2v.translate_and_query(result[0])
h2v.vso_client.get(vso_results[0]).wait()
# Out:
# ERROR:suds.umx.typed:Schema:0x10d4f6cf8
# (raw)
#    <xsd:schema elementFormDefault="unqualified" targetNamespace="http://virtualsolar.org/VSO/VSOi">
#       <xsd:complexType name="QueryRequest">
#          <xsd:all>
#             <xsd:element type="xsd:float" name="version" minOccurs="0"/>
#             <xsd:element maxOccurs="1" type="VSO:QueryRequestBlock" name="block" minOccurs="1"/>
#          </xsd:all>
#       </xsd:complexType>
#       <xsd:complexType name="QueryRequestBlock">
#          <xsd:all>
#             <xsd:element type="VSO:Time" name="time" minOccurs="1"/>
#             <xsd:element type="xsd:string" name="provider" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="source" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="instrument" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="physobs" minOccurs="0"/>
#             <xsd:element type="VSO:Wave" name="wave" minOccurs="0"/>
#             <xsd:element type="VSO:Extent" name="extent" minOccurs="0"/>
#             <xsd:element type="VSO:Field" name="field" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="pixels" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="level" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="resolution" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="detector" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="filter" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="sample" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="quicklook" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="pscale" minOccurs="0"/>
#          </xsd:all>
#       </xsd:complexType>
#       <xsd:complexType name="Time">
#          <xsd:all>
#             <xsd:element type="xsd:string" name="start"/>
#             <xsd:element type="xsd:string" name="end"/>
#             <xsd:element type="xsd:string" name="near" minOccurs="0"/>
#          </xsd:all>
#       </xsd:complexType>
#       <xsd:complexType name="Wave">
#          <xsd:all>
#             <xsd:element type="xsd:string" name="wavemin"/>
#             <xsd:element type="xsd:string" name="wavemax"/>
#             <xsd:element type="xsd:string" name="waveunit"/>
#             <xsd:element type="xsd:string" name="wavetype" minOccurs="0"/>
#          </xsd:all>
#       </xsd:complexType>
#       <xsd:complexType name="Extent">
#          <xsd:all>
#             <xsd:element type="xsd:string" name="x" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="y" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="width" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="length" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="type" minOccurs="0"/>
#          </xsd:all>
#       </xsd:complexType>
#       <xsd:complexType name="Field">
#          <xsd:sequence>
#             <xsd:element maxOccurs="unbounded" type="xsd:string" name="fielditem" minOccurs="0"/>
#          </xsd:sequence>
#       </xsd:complexType>
#       <xsd:complexType name="QueryResponse">
#          <xsd:sequence>
#             <xsd:element maxOccurs="unbounded" type="VSO:ProviderQueryResponse" name="provideritem" minOccurs="0"/>
#          </xsd:sequence>
#       </xsd:complexType>
#       <xsd:complexType name="ProviderQueryResponse">
#          <xsd:all>
#             <xsd:element type="xsd:float" name="version"/>
#             <xsd:element type="xsd:string" name="provider" minOccurs="0"/>
#             <xsd:element type="xsd:int" name="no_of_records_found" minOccurs="0"/>
#             <xsd:element type="xsd:int" name="no_of_records_returned" minOccurs="0"/>
#             <xsd:element type="VSO:QueryResponseBlockArray" name="record" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="error" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="debug" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="status" minOccurs="0"/>
#          </xsd:all>
#       </xsd:complexType>
#       <xsd:complexType name="QueryResponseBlockArray">
#          <xsd:sequence>
#             <xsd:element maxOccurs="unbounded" type="VSO:QueryResponseBlock" name="recorditem" minOccurs="0"/>
#          </xsd:sequence>
#       </xsd:complexType>
#       <xsd:complexType name="QueryResponseBlock">
#          <xsd:all>
#             <xsd:element type="xsd:string" name="provider"/>
#             <xsd:element type="xsd:string" name="source" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="instrument" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="physobs" minOccurs="0"/>
#             <xsd:element type="VSO:Time" name="time"/>
#             <xsd:element type="VSO:Wave" name="wave" minOccurs="0"/>
#             <xsd:element type="VSO:Extent" name="extent" minOccurs="0"/>
#             <xsd:element type="xsd:float" name="size" minOccurs="0"/>
#             <xsd:element type="VSO:Extra" name="extra" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="info" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="datatype" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="fileurl" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="fileid" minOccurs="0"/>
#          </xsd:all>
#       </xsd:complexType>
#       <xsd:complexType name="Extra">
#          <xsd:all>
#             <xsd:element type="VSO:Thumbnail" name="thumbnail" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="flags" minOccurs="0"/>
#          </xsd:all>
#       </xsd:complexType>
#       <xsd:complexType name="Thumbnail">
#          <xsd:all>
#             <xsd:element type="xsd:string" name="hires" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="lowres" minOccurs="0"/>
#          </xsd:all>
#       </xsd:complexType>
#       <xsd:complexType name="VSOGetDataRequest">
#          <xsd:all>
#             <xsd:element type="xsd:string" name="version" minOccurs="0"/>
#             <xsd:element type="VSO:GetDataRequest" name="request"/>
#          </xsd:all>
#       </xsd:complexType>
#       <xsd:complexType name="GetDataRequest">
#          <xsd:all>
#             <xsd:element type="VSO:MethodItem" name="method" minOccurs="0"/>
#             <xsd:element type="VSO:Info" name="info" minOccurs="0"/>
#             <xsd:element type="VSO:DataContainer" name="datacontainer" minOccurs="0"/>
#          </xsd:all>
#       </xsd:complexType>
#       <xsd:complexType name="MethodItem">
#          <xsd:sequence>
#             <xsd:element maxOccurs="unbounded" type="xsd:string" name="methodtype"/>
#          </xsd:sequence>
#       </xsd:complexType>
#       <xsd:complexType name="Info">
#          <xsd:all>
#             <xsd:element type="xsd:string" name="email"/>
#             <xsd:element type="xsd:string" name="host" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="user" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="directory" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="password" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="address" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="required" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="site" minOccurs="0"/>
#          </xsd:all>
#       </xsd:complexType>
#       <xsd:complexType name="DataContainer">
#          <xsd:sequence>
#             <xsd:element maxOccurs="unbounded" type="VSO:DataRequestItem" name="datarequestitem" minOccurs="0"/>
#          </xsd:sequence>
#       </xsd:complexType>
#       <xsd:complexType name="DataRequestItem">
#          <xsd:all>
#             <xsd:element type="xsd:string" name="provider"/>
#             <xsd:element type="VSO:FileidItem" name="fileiditem"/>
#          </xsd:all>
#       </xsd:complexType>
#       <xsd:complexType name="FileidItem">
#          <xsd:sequence>
#             <xsd:element maxOccurs="unbounded" type="xsd:string" name="fileid"/>
#          </xsd:sequence>
#       </xsd:complexType>
#       <xsd:complexType name="VSOGetDataResponse">
#          <xsd:sequence>
#             <xsd:element maxOccurs="unbounded" type="VSO:GetDataResponseItem" name="getdataresponseitem" minOccurs="0"/>
#          </xsd:sequence>
#       </xsd:complexType>
#       <xsd:complexType name="GetDataResponseItem">
#          <xsd:all>
#             <xsd:element type="xsd:string" name="version"/>
#             <xsd:element name="info" minOccurs="0">
#                <xsd:complexType>
#                   <xsd:sequence>
#                      <xsd:element maxOccurs="unbounded" type="xsd:string" name="infoitem"/>
#                   </xsd:sequence>
#                </xsd:complexType>
#             </xsd:element>
#             <xsd:element type="xsd:string" name="provider" minOccurs="0"/>
#             <xsd:element type="VSO:GetDataItem" name="getdataitem" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="status" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="debug" minOccurs="0"/>
#             <xsd:element type="xsd:string" name="details" minOccurs="0"/>
#             <xsd:element type="VSO:MethodItem" name="method" minOccurs="0"/>
#          </xsd:all>
#       </xsd:complexType>
#       <xsd:complexType name="GetDataItem">
#          <xsd:sequence>
#             <xsd:element maxOccurs="unbounded" type="VSO:DataItem" name="dataitem" minOccurs="0"/>
#          </xsd:sequence>
#       </xsd:complexType>
#       <xsd:complexType name="DataItem">
#          <xsd:all>
#             <xsd:element type="xsd:string" name="provider"/>
#             <xsd:element type="xsd:string" name="url" minOccurs="0"/>
#             <xsd:element type="VSO:FileidItem" name="fileiditem"/>
#          </xsd:all>
#       </xsd:complexType>
#    </xsd:schema>
# (model)
#    <Complex:0x11819c590 name="QueryRequest">
#       <All:0x109ece690>
#          <Element:0x109e9a0d0 name="version" type="(u'float', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e9af50 name="block" type="(u'QueryRequestBlock', u'http://virtualsolar.org/VSO/VSOi')" />
#       </All>
#    </Complex>
#    <Complex:0x109e007d0 name="QueryRequestBlock">
#       <All:0x109e9a290>
#          <Element:0x109e9a390 name="time" type="(u'Time', u'http://virtualsolar.org/VSO/VSOi')" />
#          <Element:0x109e9a9d0 name="provider" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e9abd0 name="source" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e9aad0 name="instrument" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e9add0 name="physobs" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e9ae50 name="wave" type="(u'Wave', u'http://virtualsolar.org/VSO/VSOi')" />
#          <Element:0x109e9ae90 name="extent" type="(u'Extent', u'http://virtualsolar.org/VSO/VSOi')" />
#          <Element:0x109e9acd0 name="field" type="(u'Field', u'http://virtualsolar.org/VSO/VSOi')" />
#          <Element:0x109e9ad50 name="pixels" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e9ab50 name="level" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e9ab90 name="resolution" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e9a690 name="detector" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e9a710 name="filter" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e9a750 name="sample" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e9a590 name="quicklook" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e9a610 name="pscale" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#       </All>
#    </Complex>
#    <Complex:0x109ec44d0 name="Time">
#       <All:0x109e9a410>
#          <Element:0x109e91210 name="start" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e91950 name="end" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e913d0 name="near" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#       </All>
#    </Complex>
#    <Complex:0x109e9a490 name="Wave">
#       <All:0x109e915d0>
#          <Element:0x109e91b10 name="wavemin" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e91d10 name="wavemax" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e91c10 name="waveunit" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e91f10 name="wavetype" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#       </All>
#    </Complex>
#    <Complex:0x109e9a450 name="Extent">
#       <All:0x109e91f90>
#          <Element:0x109e91e10 name="x" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e91e90 name="y" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e91c90 name="width" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e91cd0 name="length" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e917d0 name="type" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#       </All>
#    </Complex>
#    <Complex:0x109e914d0 name="Field">
#       <Sequence:0x109e91850>
#          <Element:0x109e91750 name="fielditem" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#       </Sequence>
#    </Complex>
#    <Complex:0x109e91fd0 name="QueryResponse">
#       <Sequence:0x109e91550>
#          <Element:0x109e91110 name="provideritem" type="(u'ProviderQueryResponse', u'http://virtualsolar.org/VSO/VSOi')" />
#       </Sequence>
#    </Complex>
#    <Complex:0x109e916d0 name="ProviderQueryResponse">
#       <All:0x109e91150>
#          <Element:0x109e88a90 name="version" type="(u'float', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e88510 name="provider" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e88710 name="no_of_records_found" type="(u'int', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e88610 name="no_of_records_returned" type="(u'int', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e88c50 name="record" type="(u'QueryResponseBlockArray', u'http://virtualsolar.org/VSO/VSOi')" />
#          <Element:0x109e88e50 name="error" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e88d50 name="debug" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e88f50 name="status" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#       </All>
#    </Complex>
#    <Complex:0x109e91090 name="QueryResponseBlockArray">
#       <Sequence:0x109e88fd0>
#          <Element:0x109e88910 name="recorditem" type="(u'QueryResponseBlock', u'http://virtualsolar.org/VSO/VSOi')" />
#       </Sequence>
#    </Complex>
#    <Complex:0x109e88350 name="QueryResponseBlock">
#       <All:0x109e88990>
#          <Element:0x109e88810 name="provider" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e88890 name="source" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e88690 name="instrument" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e886d0 name="physobs" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e881d0 name="time" type="(u'Time', u'http://virtualsolar.org/VSO/VSOi')" />
#          <Element:0x109e88250 name="wave" type="(u'Wave', u'http://virtualsolar.org/VSO/VSOi')" />
#          <Element:0x109e88290 name="extent" type="(u'Extent', u'http://virtualsolar.org/VSO/VSOi')" />
#          <Element:0x109e880d0 name="size" type="(u'float', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e88150 name="extra" type="(u'Extra', u'http://virtualsolar.org/VSO/VSOi')" />
#          <Element:0x109e7e490 name="info" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e7ebd0 name="datatype" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e7e110 name="fileurl" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e7e650 name="fileid" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#       </All>
#    </Complex>
#    <Complex:0x109e88e10 name="Extra">
#       <All:0x109e7e850>
#          <Element:0x109e7ed90 name="thumbnail" type="(u'Thumbnail', u'http://virtualsolar.org/VSO/VSOi')" />
#          <Element:0x109e7ef90 name="flags" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#       </All>
#    </Complex>
#    <Complex:0x109e889d0 name="Thumbnail">
#       <All:0x109e7ee90>
#          <Element:0x109e7ef50 name="hires" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e7ea50 name="lowres" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#       </All>
#    </Complex>
#    <Complex:0x109e7e750 name="VSOGetDataRequest">
#       <All:0x109e7ead0>
#          <Element:0x109e7e950 name="version" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e7e9d0 name="request" type="(u'GetDataRequest', u'http://virtualsolar.org/VSO/VSOi')" />
#       </All>
#    </Complex>
#    <Complex:0x109e7ef10 name="GetDataRequest">
#       <All:0x109e7e7d0>
#          <Element:0x109e7e310 name="method" type="(u'MethodItem', u'http://virtualsolar.org/VSO/VSOi')" />
#          <Element:0x109e7e390 name="info" type="(u'Info', u'http://virtualsolar.org/VSO/VSOi')" />
#          <Element:0x109e7e3d0 name="datacontainer" type="(u'DataContainer', u'http://virtualsolar.org/VSO/VSOi')" />
#       </All>
#    </Complex>
#    <Complex:0x109e7eb10 name="MethodItem">
#       <Sequence:0x109e7e210>
#          <Element:0x109e7e0d0 name="methodtype" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#       </Sequence>
#    </Complex>
#    <Complex:0x109e7e810 name="Info">
#       <All:0x109e745d0>
#          <Element:0x109e74050 name="email" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e74250 name="host" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e74150 name="user" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e74790 name="directory" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e74990 name="password" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e74890 name="address" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e74ed0 name="required" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e74fd0 name="site" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#       </All>
#    </Complex>
#    <Complex:0x109e7e090 name="DataContainer">
#       <Sequence:0x109e74b90>
#          <Element:0x109e74a90 name="datarequestitem" type="(u'DataRequestItem', u'http://virtualsolar.org/VSO/VSOi')" />
#       </Sequence>
#    </Complex>
#    <Complex:0x109e74d10 name="DataRequestItem">
#       <All:0x109e74b10>
#          <Element:0x109e74950 name="provider" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e74450 name="fileiditem" type="(u'FileidItem', u'http://virtualsolar.org/VSO/VSOi')" />
#       </All>
#    </Complex>
#    <Complex:0x109e74c50 name="FileidItem">
#       <Sequence:0x109e744d0>
#          <Element:0x109e743d0 name="fileid" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#       </Sequence>
#    </Complex>
#    <Complex:0x109e74910 name="VSOGetDataResponse">
#       <Sequence:0x109e741d0>
#          <Element:0x109e69e50 name="getdataresponseitem" type="(u'GetDataResponseItem', u'http://virtualsolar.org/VSO/VSOi')" />
#       </Sequence>
#    </Complex>
#    <Complex:0x109e74350 name="GetDataResponseItem">
#       <All:0x109e69190>
#          <Element:0x109e69290 name="version" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e698d0 name="info">
#             <Complex:0x109e699d0>
#                <Sequence:0x109e69d50>
#                   <Element:0x109e69c50 name="infoitem" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#                </Sequence>
#             </Complex>
#          </Element>
#          <Element:0x109e69ad0 name="provider" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e69cd0 name="getdataitem" type="(u'GetDataItem', u'http://virtualsolar.org/VSO/VSOi')" />
#          <Element:0x109e69bd0 name="status" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e69a50 name="debug" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e69a90 name="details" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e69590 name="method" type="(u'MethodItem', u'http://virtualsolar.org/VSO/VSOi')" />
#       </All>
#    </Complex>
#    <Complex:0x109e69710 name="GetDataItem">
#       <Sequence:0x109e69610>
#          <Element:0x109e69510 name="dataitem" type="(u'DataItem', u'http://virtualsolar.org/VSO/VSOi')" />
#       </Sequence>
#    </Complex>
#    <Complex:0x109e69390 name="DataItem">
#       <All:0x109e69310>
#          <Element:0x109e61110 name="provider" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e61850 name="url" type="(u'string', u'http://www.w3.org/2001/XMLSchema')" />
#          <Element:0x109e61f90 name="fileiditem" type="(u'FileidItem', u'http://virtualsolar.org/VSO/VSOi')" />
#       </All>
#    </Complex>
# []

# %% [markdown]
# # Listing 3.7 - helio.py

# %%
from sunpy.net.helio import hec
hc = hec.Client()
tstart, tend = "2011-06-07T06:00:00", "2011-06-07T12:00:00"
event_type = "cme"

# From all the catalogues these which name contain our event of interest
catalogues = hc.get_table_names()
catalogues_event = [l[0] for l in catalogues 
                     if event_type in l[0] and 'list' not in l[0]]

# Query all the catalogues that comes from cactus
results = [hc.time_query(tstart, tend, event) 
            for event in catalogues_event if 'cactus' in event]
for cat in results:
     print "{cat} has {nres} results".format(cat = cat.ID, \
                                             nres = len(cat.array))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-964b1551cff5> in <module>()
#       1 from sunpy.net.helio import hec
# ----> 2 hc = hec.Client()
#       3 tstart, tend = "2011-06-07T06:00:00", "2011-06-07T12:00:00"
#       4 event_type = "cme"
#       5
#
# AttributeError: 'module' object has no attribute 'Client'

# %% [markdown]
# # Listing 3.8 - helioviewer.py

# %%
from sunpy.net.helioviewer import HelioviewerClient
hv = HelioviewerClient()
hv.download_png("2099/01/01", 6,
                 "[SDO,AIA,AIA,304,1,100],[SDO,AIA,AIA,193,1,50],"+
                 "[SOHO,LASCO,C2,white-light,1,100]",
                 x0=0, y0=0, width=768, height=768)
# Out:
# '/Users/schriste/sunpy/data/2099_01_01_00_00_00_AIA_304__AIA_193__LASCO_C2.3.png'

# %% [markdown]
# # Listing 3.9 - helioviewer2.py

# %%
import sunpy.map
filepath = hv.download_jp2("2012/07/05 00:30:00",
                            observatory='SDO',
                            instrument="HMI", detector="HMI", 
                            measurement="continuum")
sunpy.map.Map(filepath).submap([200, 550], [-400, -200]).peek()

# %% [markdown]
# # Listing 3.10 - database.py

# %%
from sunpy.net import vso
from sunpy.database import Database
database = Database("sqlite:///")
database.download(
    vso.attrs.Time("2012-08-05", "2012-08-05 00:00:05"),
    vso.attrs.Instrument('AIA'))
len(database)
# Out:
# 2

# %%
from sunpy.database.tables import display_entries
print display_entries(
     database,
     ["id", "observation_time_start", "wavemin", "wavemax"])
# Out:
# id observation_time_start wavemin wavemax
# -- ---------------------- ------- -------
# 1  2012-08-05 00:00:01    9.4     9.4
# 2  2012-08-05 00:00:02    33.5    33.5

# %% [markdown]
# # Listing 4.1 - util1.py

# %%
from sunpy import wcs
print(wcs.convert_hg_hpc(10, 53))
# Convert that position back to heliographic coordinates
print(wcs.convert_hpc_hg(100.49, 767.97))
# Try to convert a position which is not on the Sun to HG
print(wcs.convert_hpc_hg(-1500, 0))
# Convert sky coordinate to a position in HCC
print(wcs.convert_hpc_hcc(-300, 400, z=True))
# Out:
# (100.49244115330731, 767.97438321917502)
# (9.9996521808465175, 52.999563684874893)
# (nan, nan)
# (-216716967.63331246, 288956420.9477042, 594364636.2208252)

# %% [markdown]
# # Listing 4.2 - util2.py

# %%
from sunpy.sun import constants
print(constants.mass)
# Verify the average density of the Sun and convert to cgs
(constants.mass/constants.volume).cgs
# Search for the age of the Sun
print(constants.find('age'))
constants.value('age'), constants.unit('age')
# Out:
#   Name   = Solar mass
#   Value  = 1.9891e+30
#   Error  = 5e+25
#   Units  = kg
#   Reference = Allen's Astrophysical Quantities 4th Ed.
# ['age', 'average angular size', 'average density', 'average intensity']
# (4600000000.0, Unit("yr"))
